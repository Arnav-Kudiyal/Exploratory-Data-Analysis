# %%
import pandas as pd

# %%
data = pd.read_csv("school.csv")

# %%
data.head()
# Out:
#    SR.NO.  SCH.\nCODE  DISTRICT  \
# 0       1        1001  Bilaspur
# 1       2        1002  Bilaspur
# 2       3        1003  Bilaspur
# 3       4        1004  Bilaspur
# 4       5        1005  Bilaspur
#
#                               SCHOOL CODE WITH PLACE  \
# 0    1001 - AMARPUR - GOVT SR SEC SCHOOL -\nBilaspur
# 1   1002 - AUHAR - SARSWATI VIDYA MANDIR -\nBilaspur
# 2      1003 - AUHAR - GOVT SR SEC SCHOOL -\nBilaspur
# 3  1004 - BADDU (DADHOG) - GOVT SR SEC\nSCHOOL - ...
# 4  1005 - BADGAON - S.BHAGAT SINGH HIGH\nSCHOOL -...
#
#                          SCHOOL EMAIL ID  CONTACT\nPERSON NAME   CONTACT\nNO  \
# 0  PRINCIPALAMARPUR0150@\nREDIFFMAIL.COM          LAXMAN SINGH  9.418043e+09
# 1                    svmauhar9@gmail.com  RAJESH KUMAR\nSHARMA  8.219816e+09
# 2        principalauhar2@rediffmail. com      Tilak Raj Shukla  9.817197e+09
# 3   principalbadudadhog@rediff\nmail.com   Rajesh Kumar Sharma  9.418126e+09
# ...

# %%
data["CLASS"].value_counts()
# Out:
# CLASS
# PLUS TWO    2373
# MATRIC      1709
# Name: count, dtype: int64

# %%
data.shape
# Out:
# (4082, 9)

# %%
data["S. TYPE"].value_counts()
# Out:
# S. TYPE
# GOVT    2827
# PVT     1255
# Name: count, dtype: int64

# %%
data = data[data["CLASS"] != "MATRIC"]

# %%
data["CLASS"].value_counts()
# Out:
# CLASS
# PLUS TWO    2373
# Name: count, dtype: int64

# %%
data.head()
# Out:
#    SR.NO.  SCH.\nCODE  DISTRICT  \
# 0       1        1001  Bilaspur
# 2       3        1003  Bilaspur
# 3       4        1004  Bilaspur
# 5       6        1006  Bilaspur
# 7       8        1008  Bilaspur
#
#                               SCHOOL CODE WITH PLACE  \
# 0    1001 - AMARPUR - GOVT SR SEC SCHOOL -\nBilaspur
# 2      1003 - AUHAR - GOVT SR SEC SCHOOL -\nBilaspur
# 3  1004 - BADDU (DADHOG) - GOVT SR SEC\nSCHOOL - ...
# 5    1006 - BADGAON - GOVT SR SEC SCHOOL -\nBilaspur
# 7       1008 - BALA - GOVT SR SEC SCHOOL -\nBilaspur
#
#                          SCHOOL EMAIL ID CONTACT\nPERSON NAME   CONTACT\nNO  \
# 0  PRINCIPALAMARPUR0150@\nREDIFFMAIL.COM         LAXMAN SINGH  9.418043e+09
# 2        principalauhar2@rediffmail. com     Tilak Raj Shukla  9.817197e+09
# 3   principalbadudadhog@rediff\nmail.com  Rajesh Kumar Sharma  9.418126e+09
# 5               hmbadgaon@rediffmail.com        kuldeep singh  9.817089e+09
# ...

# %%
data = data[data["S. TYPE"] != "GOVT"]

# %%
data.head()
# Out:
#     SR.NO.  SCH.\nCODE  DISTRICT  \
# 11      12        1012  Bilaspur
# 25      26        1027  Bilaspur
# 26      27        1028  Bilaspur
# 27      28        1029  Bilaspur
# 36      37        1038  Bilaspur
#
#                                SCHOOL CODE WITH PLACE  \
# 11  1012 - BALHSEENA - RAJEEV MEMO\nPUB.SR.SEC.SCH...
# 25  1027 - BERI (HARKHAR) - DEV ADARSH\nVIDYA SR.S...
# 26  1028 - BERTHIN - JYOTI PUBLIC SR SEC\nSCHOOL -...
# 27  1029 - BERTHIN - ALPHA PUBLIC SR SEC\nSCHOOL -...
# 36  1038 - BHATER - S.VIDYA MANDIR SR SEC\nSCHOOL ...
#
#                SCHOOL EMAIL ID CONTACT\nPERSON NAME   CONTACT\nNO S. TYPE  \
# 11      rmpbalhseena@gmail.com        Pulkit Sharma  9.816359e+09     PVT
# 25  principaldavberi@gmail.com         Dinesh kumar  8.580976e+09     PVT
# 26     jyotischool94@gmail.com        Shavitri Devi  8.219176e+09     PVT
# 27      thakur.alpha@gmail.com  THAKUR DASS\nSHARMA  9.817178e+09     PVT
# ...

# %%
data = data.dropna()

# %%
data.head()
# Out:
#     SR.NO.  SCH.\nCODE  DISTRICT  \
# 11      12        1012  Bilaspur
# 25      26        1027  Bilaspur
# 26      27        1028  Bilaspur
# 27      28        1029  Bilaspur
# 41      42        1043  Bilaspur
#
#                                SCHOOL CODE WITH PLACE  \
# 11  1012 - BALHSEENA - RAJEEV MEMO\nPUB.SR.SEC.SCH...
# 25  1027 - BERI (HARKHAR) - DEV ADARSH\nVIDYA SR.S...
# 26  1028 - BERTHIN - JYOTI PUBLIC SR SEC\nSCHOOL -...
# 27  1029 - BERTHIN - ALPHA PUBLIC SR SEC\nSCHOOL -...
# 41  1043 - BILASPUR - BILASPUR PUBLIC HIGH\nSCHOOL...
#
#                      SCHOOL EMAIL ID CONTACT\nPERSON NAME   CONTACT\nNO  \
# 11            rmpbalhseena@gmail.com        Pulkit Sharma  9.816359e+09
# 25        principaldavberi@gmail.com         Dinesh kumar  8.580976e+09
# 26           jyotischool94@gmail.com        Shavitri Devi  8.219176e+09
# 27            thakur.alpha@gmail.com  THAKUR DASS\nSHARMA  9.817178e+09
# ...

# %%
data.shape
# Out:
# (471, 9)

# %%
data["DISTRICT"].value_counts()
# Out:
# DISTRICT
# Kangra            134
# Mandi              89
# Hamirpur           61
# Shimla             35
# Solan              34
# Una                29
# Kullu              27
# Bilaspur           27
# Sirmour            18
# Chamba             13
# Kinnaur             3
# Lahaul & Spiti      1
# Name: count, dtype: int64

# %%
data =data.drop(columns = ['SR.NO.'])
